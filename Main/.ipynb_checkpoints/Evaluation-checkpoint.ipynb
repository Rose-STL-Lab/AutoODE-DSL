# %%
import torch
import torch.nn as nn
import time
import numpy as np
import time
import pandas as pd
from torch.utils import data
import matplotlib.pyplot as plt
import random
import os
import warnings
warnings.filterwarnings("ignore")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Scaler

# %%
# confirmed = pd.read_csv("/home/ec2-user/SageMaker/efs/Danielle/Ray/Data/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
# recovered = pd.read_csv("/home/ec2-user/SageMaker/efs/Danielle/Ray/Data/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
# deaths = pd.read_csv("/home/ec2-user/SageMaker/efs/Danielle/Ray/Data/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
# confirmed = confirmed.copy().drop(['Province/State', "Lat", "Long"],axis =1).diff(axis = 1).iloc[:,1:]
# recovered = recovered.copy().drop(['Province/State', "Lat", "Long"],axis =1).diff(axis = 1).iloc[:,1:]
# deaths = deaths.copy().drop(['Province/State', "Lat", "Long"],axis =1).diff(axis = 1).iloc[:,1:]
# global_data = pd.concat([confirmed.sort_values(by = "6/14/20", ascending = False).iloc[:,45:], 
#                          recovered.iloc[:,45:], deaths.iloc[:,45:]], axis=1, 
#                         join='inner').values[:100].reshape(100, 3, 100).transpose(0,2,1)
# global_data[global_data < 0] = 0

# # standardization
# global_std = np.std(global_data, axis = (1), keepdims = True).reshape(1,100, 1, 3)
# global_avgs = np.mean(global_data, axis = (1), keepdims = True).reshape(1,100, 1, 3)

# %%
# first day 04/12
# list_csv[65] list_csv[72] list_csv[79]
# list_csv[84] list_csv[91] list_csv[98]
direc = "/home/ec2-user/SageMaker/efs/Danielle/Ray/Data/US_Reports/"
list_csv = sorted(os.listdir(direc))[2:]
us = []
for file in list_csv:
    sample = pd.read_csv(direc + file).set_index("Province_State")[["Confirmed",  "Recovered", "Deaths"]].sort_values(by = "Confirmed", ascending = False)
    us.append(sample.drop(['Diamond Princess', 'Grand Princess']))
us = pd.concat(us, axis=1, join='inner') 
us_data = us.values.reshape(56,-1,3)
us_data[us_data!=us_data] = 0
us_data[:,:,1] += us_data[:,:,2]

# standardization
std = np.std(us_data, axis = (1), keepdims = True).reshape(1,56,1,3)
avgs = np.mean(us_data, axis = (1), keepdims = True).reshape(1,56,1,3)
# us_data = (us_data - avgs)/std
# us_data[us_data!=us_data] = 0

# %%
results = torch.load("Results/GCN.pt")
print(results["preds"].shape, results["trues"].shape)
# Out:
# (3, 56, 7, 3) (3, 56, 21, 3)

# %%
# preds = results["preds"][:,:7].reshape(3,56,7,3)*std + avgs
# trues = results["trues"][:,:21].reshape(3,56,21,3)*std + avgs
preds = results["preds"] * std + avgs
trues = results["trues"] * std + avgs

for d in range(3):
    for i in range(3):
        print(np.mean(np.abs(preds[d,:,-7:,i] - trues[d,:,-7:,i])))
print(np.mean(np.abs(preds - trues[:,:,-7:])))
# Out:
# 5729.5981178594675
# 3682.9650206865795
# 251.98624064695846
# 9498.486973597363
# 4423.023758364543
# 331.1874149776893
# 11991.982340586832
# 5914.172442909634
# 422.2678692138036
# 4693.963353204763

# %%
#data = torch.load("SuEIRD_piecewise_testcase.pt").reshape(1, 60, 6)/1000
# first day 04/13
# list_csv[84] list_csv[91] list_csv[98]
direc = "/home/ec2-user/SageMaker/efs/Danielle/Ray/Data/US_Reports/"
list_csv = sorted(os.listdir(direc))[2:]
us = []
for file in list_csv:
    sample = pd.read_csv(direc + file).set_index("Province_State")[["Confirmed",  "Recovered", "Deaths"]].sort_values(by = "Confirmed", ascending = False)
    us.append(sample.drop(['Diamond Princess', 'Grand Princess']))
us = pd.concat(us, axis=1, join='inner') 
us_data = us.values.reshape(56,-1,3)
us_data[us_data!=us_data] = 0
us_data[:,:,1] += us_data[:,:,2]

# standardization
population = pd.read_csv("/home/ec2-user/SageMaker/efs/Danielle/Ray/Data/population_states.csv", index_col=0)
scaler = population.loc[us.index].values.reshape(56, 1, 1)*1e6

ode_results = torch.load("SuEIR/SuEIRD_0706.pt")
ode_preds = ode_results["preds"]#*scaler
ode_trues = ode_results["trues"]#*scaler

# %%
idx = 2
state = 5
#y_approx = best_model(70)
x = np.linspace(0, trues.shape[2]-1, trues.shape[2])
fig=plt.figure(figsize=(8, 6))

plt.plot(x[-6:], np.diff(preds[idx, state,:,0]), 'blue', alpha= 0.5, lw=4, linestyle = "--", label='Seq2Seq Prediction')
#plt.plot(x[-7:], ode_preds[state,-7:,0], 'red', alpha = 0.5, lw=4, linestyle = "--", label='SUEIRD approx')
plt.plot(x[1:], np.diff(trues[idx,state,:,0]), 'black', alpha=1, lw=2,  label= 'True #Infectives')
plt.axvline(14, color = "black")
plt.xlabel('Time', size = 15)
#plt.ylabel('Proportion', size = 15)
plt.xticks(size = 15)
plt.yticks(size = 15)


plt.grid(b=True, c='w', lw=2, ls='-')
plt.legend(fontsize = 15, loc = 0)

# N = 10000, I0 = 10, R0 = 0, beta = 0.8, gamma = 0.1, num_steps = 60
plt.title( "#Infected - " + us.index[state], fontsize = 20)#+ r"$N=10000, I_0 = 10, \beta = 0.8, \gamma = 0.1$"+ "- 07/06~07/12"
#plt.savefig( us.index[state] + "_I.png", dpi = 400 , bbox_inches = "tight")   #"SuEIRD_Corr_" + us.index[idx] + ".png" 
plt.show()

# %%
fig=plt.figure(figsize=(8, 6))
plt.plot(x[-7:], np.diff(preds[idx, state,:,1]), 'blue', alpha= 0.5, lw=4, linestyle = "--", label='GAT approx')
plt.plot(x[-7:], ode_preds[state,-7:,1], 'red', alpha = 0.5, lw=4, linestyle = "--", label='SUEIRD approx')
plt.plot(x, trues[idx,state,:,1], 'black', alpha=1, lw=2,  label = 'True #Removed')
plt.axvline(14, color = "black")
plt.xlabel('Time', size = 15)
#plt.ylabel('Proportion', size = 15)
plt.xticks(size = 15)
plt.yticks(size = 15)


plt.grid(b=True, c='w', lw=2, ls='-')
plt.legend(fontsize = 15, loc = 0)

# N = 10000, I0 = 10, R0 = 0, beta = 0.8, gamma = 0.1, num_steps = 60
plt.title("#Removed - " + us.index[state] + "- 07/06~07/12", fontsize = 20)#+ r"$N=10000, I_0 = 10, \beta = 0.8, \gamma = 0.1$"
#plt.savefig(us.index[state] + "_r.png", dpi = 400 , bbox_inches = "tight")   #"SuEIRD_Corr_" + us.index[idx] + ".png" 
plt.show()

# %%
fig=plt.figure(figsize=(8, 6))

plt.plot(x[-7:], preds[idx, state,:,2], 'blue', alpha= 0.5, lw=4, linestyle = "--", label='GAT approx')
plt.plot(x[-7:], ode_preds[state,-7:,2], 'red', alpha = 0.5, lw=4, linestyle = "--", label='SUEIRD approx')
plt.plot(x, trues[idx,state,:,2], 'black', alpha=1, lw=2,  label = 'True #Death')
plt.axvline(14, color = "black")
plt.xlabel('Time', size = 15)
#plt.ylabel('Proportion', size = 15)
plt.xticks(size = 15)
plt.yticks(size = 15)


plt.grid(b=True, c='w', lw=2, ls='-')
plt.legend(fontsize = 15, loc = 0)

# N = 10000, I0 = 10, R0 = 0, beta = 0.8, gamma = 0.1, num_steps = 60
plt.title("#Death - " + us.index[state] + "- 07/06~07/12", fontsize = 20)#+ r"$N=10000, I_0 = 10, \beta = 0.8, \gamma = 0.1$"
#plt.savefig(us.index[state] + "_d.png", dpi = 400 , bbox_inches = "tight")   #"SuEIRD_Corr_" + us.index[idx] + ".png" 
plt.show()
