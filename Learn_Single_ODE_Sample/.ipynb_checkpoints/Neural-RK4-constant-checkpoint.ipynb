# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from neural_odes import *
from tqdm import tqdm_notebook as tqdm
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Simple Explicit ODE Solvers to solve $\frac{dy}{dt} = f(t,y) = 2 \iff y(t) = 2t + y_0$. (Linear case)

# %%
dt = 0.01
t0 = 0
y0 = torch.Tensor([1.0]).float()
Tn = 1
t = torch.arange(t0, Tn+dt, dt).float()
N = len(t)

# %%
print(f'The number of time steps = {N-1}')
# Out:
# The number of time steps = 100

# %% [markdown]
# ### 1) 4 stage explicit Runge Kutta

# %%
# Define function
# Problem is this is a lambda function and can only learn nd array
C = 2
f = lambda t,y : C

# %%
def ode_solver(f, t, y0, solver):
    y = []
    # Inital condiiton
    y.append(y0)
    if solver == 'rk4':
        for n in range(0, N-1):
            k1 = dt * f(t[n], y[n]) #f is lambd function
            k2 = dt * f(t[n] + dt/2, y[n] + k1/2)
            k3 = dt * f(t[n] + dt/2, y[n] + k2/2)
            k4 = dt * f(t[n] + dt, y[n] + k3)
            y.append(y[n] + 1/6 * (k1 + 2*k2 + 2*k3 + k4))
            
    elif solver == 'forward_euler':
        for n in range(0,N-1):
            y.append(y[n] + dt * f(t[n],y[n]))
    else:
        print('ODE solver is not supported!')
    return torch.cat(y, dim = 0)

# %%
y_rk4 = ode_solver(f,t,y0, 'rk4')

# %% [markdown]
# ### 2) Forward Euler

# %%
y_fe = ode_solver(f, t, y0, 'forward_euler')

# %% [markdown]
#  ### Exact Solution

# %%
y_exact = 2*t + y0

# %%
plt.plot(t,y_rk4.numpy(), lw=2)
plt.plot(t,y_fe.numpy(), 'r--')
plt.plot(t,y_exact.numpy(), 'g--')
plt.legend(('RK4', 'ForwardEuler', 'Exact Sol'))

# %%
err_rk = torch.max(torch.abs(y_rk4-y_exact))
print(f'RK4 Absolute error = {err_rk}')
# Out:
# RK4 Absolute error = 1.9073486328125e-06

# %%
err_fe = torch.max(torch.abs(y_fe-y_exact))
print(f'Forward Euler Absolute error = {err_fe}')
# Out:
# Forward Euler Absolute error = 1.9073486328125e-06

# %%
plt.plot(t, torch.abs(y_rk4-y_exact))
plt.plot(t, torch.abs(y_fe-y_exact))
plt.legend(('RK4', 'ForwardEuler'))
plt.title('Pointwise Errors')
# Out:
# Text(0.5, 1.0, 'Pointwise Errors')

# %% [markdown]
# ## Use simple embedding to learn initial condition $y_0$ or $z_{t_0}$ in time series context.

# %%
class InitialCondRNN(nn.Module):      
    def __init__(self, num_ts, num_params):
        super(InitialCondRNN, self).__init__()  
        self.num_ts = num_ts # cardinality = number of time series = 1 for now
        self.num_params = num_params
        self.embedding = nn.Embedding(num_ts, num_params)
    
    def forward(self, f, t):
        y0 = self.embedding(torch.arange(self.num_ts))
        return ode_solver(f, t, y0.squeeze(0), solver)

# %%
num_ts = 1
num_params = 1 #learning only initial condition
model = InitialCondRNN(num_ts, num_params)
optimizer = torch.optim.Adam(model.parameters(), 0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size= 1, gamma=0.95)

# %%
# %%time
num_epochs = 1500
solver = 'rk4'
loss_fun = torch.nn.MSELoss()

tqdm_epochs = tqdm(range(num_epochs))

for e in tqdm_epochs:
    #forward pass
    y = model(f, t)
    Loss = loss_fun(y, y_exact)
    optimizer.zero_grad()
    Loss.backward()
    optimizer.step()
    tqdm_epochs.set_postfix({'loss': torch.sum(Loss).item()})
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel/__main__.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=1500.0), HTML(value='')))
# CPU times: user 12.8 s, sys: 63.2 ms, total: 12.8 s
# Wall time: 12.7 s

# %%
model.embedding(torch.arange(num_ts)) #initial condition
# Out:
# tensor([[1.0000]], grad_fn=<EmbeddingBackward>)

# %%
error = torch.max(torch.abs(y-y_exact))
error
# Out:
# tensor(9.5367e-07, grad_fn=<MaxBackward1>)

# %%
# after 1500 iterations
plt.plot(t.data.numpy(), y.data.numpy(), '--')
plt.plot(t.data.numpy(), y_exact.data.numpy())
plt.legend(('RK4_RNN', 'Exact Sol'))
plt.xlabel('t')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Use simple embedding to learn initial condition $y_0$ or $z_{t_0}$ and in time series context and the function $f(t,y)$

# %%
class InitialCond_and_FC(nn.Module):
    def __init__(self, num_ts, num_params):
        super(InitialCond_and_FC, self).__init__()  
        self.num_ts = num_ts # cardinality = number of time series = 1 for now
        self.num_params = num_params
        self.num_vars = 2 #(t,y)
        #self.embedding = nn.Embedding(num_ts, num_params)
        #self.embedding.weight.data.uniform_(1, 1)
        self.y0 = torch.nn.Parameter(torch.cuda.FloatTensor([[1.0]]))#

        # learn f with 1 layer can only learn linear functions
        self.dynamics = nn.Linear(self.num_vars, 1)
        #self.dynamics.weight.data.uniform_(1, 1)

    def forward(self, t):
        #y0 = self.embedding(torch.arange(self.num_ts).to(device))
        # inline Rk4 solver
        y = []
        # Inital condiiton
        y.append(self.y0)
        # Missing forward euler option as in the cosine case
        for n in range(0, N-1):
           # print(t[n].reshape(1,1).shape, y[n].shape,torch.cat([t[n].reshape(1,1), y[n]]).shape)
            f1 = self.dynamics(torch.cat([t[n].reshape(1,1), y[n]]).reshape(self.num_ts,self.num_vars))
            k1 = dt * f1
            f2 = self.dynamics(torch.cat([(t[n] + dt/2).reshape(1,1), y[n] + k1/2]).reshape(self.num_ts,self.num_vars))
            k2 = dt * f2
            f3 = self.dynamics(torch.cat([(t[n] + dt/2).reshape(1,1), y[n] + k2/2]).reshape(self.num_ts,self.num_vars))
            k3 = dt * f3
            f4 = self.dynamics(torch.cat([(t[n] + dt).reshape(1,1), y[n] + k3]).reshape(self.num_ts,self.num_vars))
            k4 = dt * f4
            y.append(y[n] + 1/6 * (k1 + 2*k2 + 2*k3 + k4))
        return torch.cat(y, dim=0)

# %%
num_ts = 1
num_params = 1 #learning only initial condition
model = InitialCond_and_FC(num_ts, num_params).to(device)
optimizer = torch.optim.RMSprop(model.parameters(), 0.01)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size= 1, gamma=0.99)

# %%
# %%time
num_epochs = 100
solver = 'rk4'
loss_fun = torch.nn.MSELoss(size_average = False)

tqdm_epochs = tqdm(range(num_epochs))

for e in tqdm_epochs:
    #forward pass
    y = model(t.to(device))
    Loss = loss_fun(y.to(device), y_exact.to(device))
    optimizer.zero_grad()
    Loss.backward()
    #print(Loss)
    optimizer.step()
    tqdm_epochs.set_postfix({'loss': torch.sum(Loss).item()})
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel/__main__.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([101])) that is different to the input size (torch.Size([101, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# CPU times: user 19.4 s, sys: 12.1 ms, total: 19.4 s
# Wall time: 19.3 s

# %%
Loss.item()
# Out:
# 0.34000250697135925

# %%
y = model(t.to(device))
# after 4500 iterations reasonable at 3000
plt.plot(t.cpu().data.numpy(),y.cpu().data.numpy(), '--')
plt.plot(t.cpu().data.numpy(),y_exact.cpu().data.numpy())
plt.legend(('RK4_FC', 'Exact Sol'))
plt.xlabel('t')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
# after 4500 iterations reasonable at 3000
plt.plot(t.cpu().data.numpy(),y.cpu().data.numpy(), '--')
plt.plot(t.cpu().data.numpy(),y_exact.cpu().data.numpy())
plt.legend(('RK4_FC', 'Exact Sol'))
plt.xlabel('t')
plt.ylabel('y')
#plt.savefig("RK4_FC_failure.png", dpi = 300 , bbox_inches = "tight")

# %%
for n in range(N):
    print(model.dynamics(torch.cat([t[n].reshape(1,1).to(device), y[n].reshape(1,1)]).reshape(1,2)))
sum_f / N
# Out:
# tensor([[-0.0792]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0771]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0750]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0728]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0707]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0685]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0663]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0641]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0619]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0597]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0574]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0551]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0529]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0506]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0482]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0459]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0436]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0412]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0388]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0364]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0340]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0316]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0291]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0267]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0242]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0217]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0192]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0167]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0141]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0116]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0090]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0064]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0038]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[-0.0012]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0015]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0041]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0068]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0095]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0122]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0149]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0176]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0203]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0231]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0259]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0287]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0315]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0343]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0371]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0400]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0428]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0457]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0486]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0515]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0545]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0574]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0604]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0633]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0663]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0693]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0723]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0754]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0784]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0815]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0846]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0877]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0908]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0939]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.0970]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1002]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1033]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1065]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1097]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1129]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1162]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1194]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1227]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1259]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1292]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1325]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1358]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1392]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1425]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1459]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1492]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1526]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1560]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1594]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1629]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1663]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1698]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1733]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1767]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1802]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1838]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1873]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1908]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1944]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.1980]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.2016]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.2052]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.2088]], device='cuda:0', grad_fn=<AddmmBackward>)
# tensor([[0.4589]], device='cuda:0', grad_fn=<DivBackward0>)

# %%
# model.embedding(torch.arange(num_ts).to(device)) #initial condition
# model.dynamics(torch.cat([t[0].reshape(1,1).to(device), y[0].reshape(1,1)]).reshape(1,2))
# sum_f = 0
# for n in range(N):
#     sum_f += model.dynamics(torch.cat([t[n].reshape(1,1).to(device), y[n].reshape(1,1)]).reshape(1,2))
# sum_f / N # should be close to C = 2
# torch.abs(C-sum_f / N)
# model.dynamics(torch.cat([t[100].reshape(1,1).to(device), y[100].reshape(1,1)]).reshape(1,2))
